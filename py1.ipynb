# %%
#from google.colab import auth
#auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/Shared drives/Coding/Data/klaza_gps_data.csv')
df.head()
# Out:
# <ipython-input-3-f8f3df4fd21b>:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/Shared drives/Coding/Data/klaza_gps_data.csv')
#       event-id  visible timestamp  location-long  location-lat  \
# 0  28041249666     True   00:00.0     -137.78938      61.94196
# 1  26575287129     True   00:00.0     -137.78938      61.94196
# 2  28041249669     True   00:00.0     -137.73941      61.95747
# 3  26575287132     True   00:00.0     -137.73936      61.95745
# 4  26575287133     True   00:00.0     -137.73941      61.95747
#
#             comments  event-group-id migration-stage  \
# 0  Rangifer tarandus             NaN             NaN
# 1  Rangifer tarandus    1.938075e+09             NaN
# 2  Rangifer tarandus             NaN             NaN
# 3  Rangifer tarandus    1.938075e+09             NaN
# 4  Rangifer tarandus    1.938075e+09             NaN
#
# ...
